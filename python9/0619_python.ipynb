# %%
import pandas as pd

# 샘플 데이터프레임 생성
data = {'이름': ['John', 'Steve', 'Sarah', 'Ann', 'Mike'],
        '나이': ['25', '32', '28', '35', '41'],
        '성별': ['남', '남', '여', '여', '남'],
        '키': ['175', '180', '163', '155', '190']}
df = pd.DataFrame(data)

# %%
import pandas as pd

# 데이터프레임 생성
data = {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
        'age': [25, 30, 35, 40, 45],
        'city': ['New York', 'Paris', 'London', 'Berlin', 'Tokyo']}
df = pd.DataFrame(data)

# 열 추가 방법 1: 기존 열을 이용하여 새로운 열 추가
df['age2'] = df['age'] + 1

# 열 추가 방법 2: insert() 메소드를 이용하여 특정 위치에 열 추가
df.insert(loc=2, column='gender', value=['F', 'M', 'M', 'M', 'F'])

# 열 추가 방법 3: assign() 메소드를 이용하여 여러 개의 열 한 번에 추가
df = df.assign(age3=[26, 31, 36, 41, 46], height=[160, 170, 180, 175, 165])

# 출력
print(df)
# Out:
#       name  age gender      city  age2  age3  height
# 0    Alice   25      F  New York    26    26     160
# 1      Bob   30      M     Paris    31    31     170
# 2  Charlie   35      M    London    36    36     180
# 3    David   40      M    Berlin    41    41     175
# 4      Eva   45      F     Tokyo    46    46     165

# %%
import pandas as pd

data = {'이름': ['John', 'Steve', 'Sarah', 'Ann', 'Mike'],
        '나이': [25, 32, 28, 35, 41],
        '성별': ['남', '남', '여', '여', '남'],
        '키': [175, 180, 163, 155, 190]}
df = pd.DataFrame(data)

# 문제 1 '학년' 열을 추가하고, 모든 행에 '3학년'이라는 값으로 채워 넣으세요.
df['학년'] = '3학년'

# 문제 2 '국적' 열을 추가하고, 각 행에 해당하는 사람의 국적을 채워 넣으세요.
df['국적'] = ['미국', '영국', '일본', '한국', '중국']

# 문제 3 '성별'이 '여'인 행만 남기고 나머지 행을 삭제하세요.
df = df[df['성별'] == '여']

# 문제 4 '나이' 열을 기준으로 내림차순으로 행을 정렬하세요.
df = df.sort_values(by='나이', ascending=False)

# 문제 5 인덱스가 2인 행을 삭제하세요.
df = df.drop(2)

# 문제 6 아래 새로운 행 3개를 추가하세요.
new_rows = [{'이름': 'Alex', '나이': 22, '성별': '남', '키': 180, '학년': '2학년', '국적': '미국'},
            {'이름': 'Emily', '나이': 29, '성별': '여', '키': 165, '학년': '1학년', '국적': '캐나다'},
            {'이름': 'Daniel', '나이': 33, '성별': '남', '키': 175, '학년': '3학년', '국적': '호주'}]
df = pd.concat([df, pd.DataFrame([new_rows])], ignore_index=True)

# 문제 7 '이름' 열을 기준으로 오름차순으로 행을 정렬하세요.
df = df.sort_values(by='이름')

# 문제 8 '키' 열의 값을 cm에서 m로 변환하세요.
df['키'] = df['키'] / 100

# 문제 9 '성별' 열을 삭제하세요.
df = df.drop('성별', axis=1)

# 결과 확인
print(df)
# Out:
#     이름    나이     키   학년   국적  \
# 0  Ann  35.0  1.55  3학년   한국
# 1  NaN   NaN   NaN  NaN  NaN
#
#                                                    0  \
# 0                                                NaN
# 1  {'이름': 'Alex', '나이': 22, '성별': '남', '키': 180, ...
#
#                                                    1  \
# 0                                                NaN
# 1  {'이름': 'Emily', '나이': 29, '성별': '여', '키': 165,...
#
#                                                    2
# 0                                                NaN
# 1  {'이름': 'Daniel', '나이': 33, '성별': '남', '키': 175...

# %%
import pandas as pd

df = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
    'C': [1, 2, 3, 4, 5, 6, 7, 8],
    'D': [10, 20, 30, 40, 50, 60, 70, 80]
})

result = df.groupby(['A', 'B']).agg({'C': 'count', 'D': ['sum', 'mean']})
print(result)
# Out:
#               C   D
#           count sum  mean
# A   B
# bar one       1  20  20.0
#     three     1  40  40.0
#     two       1  60  60.0
# foo one       2  80  40.0
#     three     1  80  80.0
#     two       2  80  40.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 예시 데이터프레임 생성
data = {'Grade': np.random.randint(1, 4, size=30),
        'Score': np.random.randint(50, 100, size=30),
        'Subject': np.random.choice(['Math', 'English', 'Korean'], size=30)}
df = pd.DataFrame(data)

# 과목별 평균 성적 계산
pivot_table = df.pivot_table(index='Grade', columns='Subject', values='Score', aggfunc='mean')

# 선 그래프 그리기
pivot_table.plot(kind='line', marker='o')
plt.title('Average Score by Subject and Grade')
plt.xlabel('Grade')
plt.ylabel('Average Score')
plt.legend(title='Subject')
plt.xticks(pivot_table.index)
plt.show()
