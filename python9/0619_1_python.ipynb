# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.hani.co.kr/arti/list.html?sec=news&subsec=politics"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")
titles = soup.find_all("h4", class_="article-title")
for title in titles:  
    print(title.text.strip())
# Out:
# 서울백병원 문 닫으면? 중구보건소 “도심 응급의료 공백 우려”
# [속보] 이규민 평가원장 “6월 모의평가 책임지고 사임”
# 사교육 부르는 ‘킬러 문항’ 죽이고 ‘사교육 핵심’ 자사고는 살린다
# 평범한 우리도, 세상을 바꿀 수 있다
# 인간중심 간호 전문인재 양성…‘국시 100% 합격’
# 뜨겁다 뜨거워…폭염에도 삶은 계속되고, 방법은 다 있다
# 낮에 모인 ‘육퇴’ 동지들 “엄마가 행복해야 아이도 행복하다”
# “오래된 물건 자랑하랬더니, 엄마아빠 쓰던 연필깎이 갖고 와”
# ‘오징어 게임 2’ 캐스팅 영상에 여성 0…넷플릭스에 물어보니
# ‘킬러 문항→사교육비→저출산’ 윤 대통령의 문제의식 배경
# 대안학교 가려면 지금부터 ‘발품’…2박3일 면접 보는 곳도
# 경기부양 욕심이 키운 ‘카드대란’ 연착륙에 성공하다
# 14살 스페이스X 신입사원 “채용 때 나이 편견 버리길 희망”
# 파업 유발시킨 ‘회사 불법’ 방치한 대법 판결…노란봉투법이 답이다
# 스위스, 법인세율 최저 11→15%로…국민투표 78.5% 찬성

# %%
#네이버 블로그에서 특정 키워드에 대한 포스트 제목과 링크를 가져오는 예시

import requests
from bs4 import BeautifulSoup

# 네이버 블로그에서 키워드 "파이썬"에 대한 포스트 검색 페이지에서 HTML 코드 가져오기
url = 'https://search.naver.com/search.naver'
params = {'query': '파이썬', 'where': 'blog'}
response = requests.get(url, params=params)
#print(response.url)

# HTML 코드 파싱하기
soup = BeautifulSoup(response.text, 'html.parser')

# 포스트 정보 태그 가져오기
posts = soup.select('.total_tit')

# 포스트 정보 출력하기
for post in posts:
    # 제목과 링크 가져오기
    title = post.text
    link = post.get('href')
    print(title)
    print(link)
    print('-' * 50)
# Out:
# 파이썬 학원 다녀본 후기
# https://blog.naver.com/wkddpfka1/223123747880
# --------------------------------------------------
# 시대에 파이썬 독학을 위한 책 추천, 코딩은 처음이라 파이썬!
# https://blog.naver.com/nkj2001/223095668983
# --------------------------------------------------
# 파이썬으로 최대공약수 계산기 만들고 값 구하는법
# https://blog.naver.com/hj_bw/223122660212
# --------------------------------------------------
# 파이썬 Python 개발 도구 PyCharm 환경 설정 하는 방법
# https://mainia.tistory.com/4545
# --------------------------------------------------
# 데이터안심구역에서 인공지능 빅데이터 분석과 파이썬 무료...
# https://blog.naver.com/moimoi1357/223116965255
# --------------------------------------------------
# 대구파이썬학원. 중위권 진로로드맵
# https://blog.naver.com/hma778/223117429542
# --------------------------------------------------
# 파이썬 마스터 자격증 1급, 2급, 3급 시험 일정 그리고 공부 방법
# https://blog.naver.com/roseandme7753/223129318796
# --------------------------------------------------
# 웹크롤링 파이썬 몰라도 챗GPT 사용법만 알아도 된다.
# https://blog.naver.com/ocmarketing/223040044418
# --------------------------------------------------
# 파이썬 자기개발 위해 국비지원 학원 다녔어요!
# https://blog.naver.com/lomi1856/223124530766
# --------------------------------------------------
# 맥북 파이썬, 비주얼스튜디오 설치 후 간단한 print 코딩 테스트
# https://blog.naver.com/thepoundcake/223091395849
# --------------------------------------------------
# 파이썬학원 : Python기초부터 IT취업까지
# https://blog.naver.com/ridesafe/223054476246
# --------------------------------------------------
# 강남파이썬학원 : 자기개발로 시작하여 취업까지
# https://blog.naver.com/urmyver/223079591746
# --------------------------------------------------
# 빅데이터 분석, 파이썬 무료 강의 데이터안심구역 방문 후기
# https://blog.naver.com/sanghyo1026/223116681160
# --------------------------------------------------
# 파이썬 프로그래밍 입문자가 코딩공부에 도움이 되는 책을...
# https://blog.naver.com/kr208h/223119418578
# --------------------------------------------------
# 도전: 파이썬으로 "텔로" 드론 조종하기!!!
# https://blog.naver.com/makerhanssem/223060162996
# --------------------------------------------------
# 파이썬 프로그래밍 PYTHON 특징, 전망
# https://blog.naver.com/sg90929/223069662333
# --------------------------------------------------
# 탄탄해야 심화에서 잘 배울 수 있다! : 대구파이썬학원
# https://blog.naver.com/chan63078/223127935843
# --------------------------------------------------
# 빅데이터 분석 및 파이썬 무료 강의 데이터안심구역 방문기
# https://blog.naver.com/aiwositai/223095770510
# --------------------------------------------------
# Python(파이썬) 셀레니움(Selenium) 이용해서 웹 크롤링...
# https://mainia.tistory.com/5742
# --------------------------------------------------
# [IT 기초] 모두의 한국어 텍스트분석 with 파이썬 : 자연어...
# https://blog.naver.com/iroone/223131609515
# --------------------------------------------------
# 파이썬 설치 해서 챗GPT 사용법 120% 확장하자.
# https://blog.naver.com/ocmarketing/223039994944
# --------------------------------------------------
# 진해파이썬학원 데이터를 분석하고싶다? 기초부터 배우자!
# https://blog.naver.com/gnuoes66/223129433794
# --------------------------------------------------
# 파이썬 독학 입문자 추천 도서 코딩은 처음이라 with 파이썬...
# https://blog.naver.com/onetoppro/223076208050
# --------------------------------------------------
# 파이썬 프로그래밍 언어 독학 책 추천, 무료 동영상 강의까지
# https://blog.naver.com/dsw99248/223125083140
# --------------------------------------------------
# 로사쌤의 파이썬 기초 문법 정리 pdf - 스마트스토어 등록
# https://blog.naver.com/happynut/223117962046
# --------------------------------------------------
# 파이썬 BeautifulSoup 모듈을 이용한 웹 크롤링 기초
# https://blog.naver.com/tank100/223128588391
# --------------------------------------------------
# 파이썬머신러닝 교육, 제대로 배워봅시다
# https://blog.naver.com/ridesafe/223021700365
# --------------------------------------------------
# [Python(파이썬)] List Comprehension
# https://blog.naver.com/smhrd_official/223123276096
# --------------------------------------------------
# 파이썬 책 코딩 도장 서평, 파이썬독학을 위한 도서
# https://blog.naver.com/shiaru/223013462511
# --------------------------------------------------
# 대구파이썬학원 : IT 공부 시작!
# https://blog.naver.com/chan63078/223123445198
# --------------------------------------------------

# %%
# 구글 뉴스의 제목과 링크를 출력하는 예시

import requests
from bs4 import BeautifulSoup

url = 'https://news.google.com/topstories?hl=ko&gl=KR&ceid=KR:ko'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

titles = soup.select('.WwrzSb')
for title in titles:
    print(title.get('aria-label'))
    print('https://news.google.com' + title['href'][1:])
    print('-' * 50)
# Out:
# None
# https://news.google.com/articles/CBMiRWh0dHBzOi8vaW1uZXdzLmltYmMuY29tL25ld3MvMjAyMy9wb2xpdGljcy9hcnRpY2xlLzY0OTQ4MzBfMzYxMTkuaHRtbNIBRWh0dHBzOi8vaW1uZXdzLmltYmMuY29tL25ld3MvMjAyMy9wb2xpdGljcy9hcnRpY2xlLzY0OTQ4MzBfMzYxMjAuaHRtbA?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CCAiC0E2X3FjUF9UVGM0mAEB?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CBMiOmh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9wb2xpdGljcy9hc3NlbWJseS8xMDk2NTIzLmh0bWzSAQA?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CCAiC0xlSFFEcXgtNFJFmAEB?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CBMiOGh0dHBzOi8vd3d3LnlvbmhhcG5ld3N0di5jby5rci9uZXdzL01ZSDIwMjMwNjE5MDAwNTAwNjQx0gEA?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CBMiL2h0dHBzOi8vd3d3LnluYS5jby5rci92aWV3L0FLUjIwMjMwNjE4MDM2ODUyMDgz0gExaHR0cHM6Ly9tLnluYS5jby5rci9hbXAvdmlldy9BS1IyMDIzMDYxODAzNjg1MjA4Mw?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CBMiTGh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9pbnRlcm5hdGlvbmFsL2ludGVybmF0aW9uYWxfZ2VuZXJhbC8xMDk2NDc5Lmh0bWzSAQA?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CBMiRmh0dHBzOi8vaW1uZXdzLmltYmMuY29tL3JlcGxheS8yMDIzL253dG9kYXkvYXJ0aWNsZS82NDk0NzA2XzM2MjA3Lmh0bWzSAUZodHRwczovL2ltbmV3cy5pbWJjLmNvbS9yZXBsYXkvMjAyMy9ud3RvZGF5L2FydGljbGUvNjQ5NDcwNl8zNjIwOC5odG1s?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CBMiQmh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9wb2xpdGljcy9wb2xpdGljc19nZW5lcmFsLzEwOTY1MTguaHRtbNIBAA?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------
# None
# https://news.google.com/articles/CBMiQmh0dHBzOi8vd3d3LnlvbmhhcG5ld3N0di5jby5rci9uZXdzL01ZSDIwMjMwNjE5MDA1MzAwNjQxP3NydD1sJmQ9WdIBAA?hl=ko&gl=KR&ceid=KR%3Ako
# --------------------------------------------------

# %%
#다음 영화 예매 순위 정보를 출력하는 예시

import requests
from bs4 import BeautifulSoup

url = 'https://movie.daum.net/ranking/reservation'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

rank_list = soup.select('div.thumb_cont > strong > a')
rank_rate = soup.select('span.txt_append > span > span')

for rank, title in enumerate(rank_list, 1):
    print(f'{rank}위: {title.text} 예매율({rank_rate[rank-1].text})')
# Out:
# 1위: 스파이더맨: 어크로스 더 유니버스 예매율(8.9)
# 2위: 귀공자 예매율(26.4%)
# 3위: 엘리멘탈 예매율(8.7)
# 4위: 범죄도시3 예매율(21.0%)
# 5위: 플래시 예매율(8.8)
# 6위: 명탐정코난: 하이바라 아이 이야기 ~흑철의 미스터리 트레인 예매율(16.0%)
# 7위: 수라 예매율(6.7)
# 8위: 파이어하트 예매율(13.1%)
# 9위: 트랜스포머: 비스트의 서막 예매율(8.0)
# 10위: 비의도적 연애담 스페셜 예매율(6.6%)
# 11위: 인디아나 존스: 운명의 다이얼 예매율(10.0)
# 12위: 가디언즈 오브 갤럭시: Volume 3 예매율(3.8%)
# 13위: 인드림 예매율(10.0)
# 14위: 너의 눈을 들여다보면 예매율(1.2%)
# 15위: 어디로 가고 싶으신가요 예매율(10.0)
# 16위: 마마무: 마이콘 더 무비 예매율(1.2%)
# 17위: 1986 그 여름, 그리고 고등어통조림 예매율(7.3)
# 18위: 남은 인생 10년 예매율(1.0%)
# 19위: 엔니오: 더 마에스트로 예매율(10.0)
# 20위: 굿바이 예매율(0.9%)

# %%
# for li in li_list:
#     rank = li.select_one('.rank_num').text
#     name = li.select_one('.link_txt').text
#     see = li.select_one('.ico_see').text
#     grade = li.select_one('.txt_grade').text
#     num = li.select_one('.txt_num').text[:-1]
#     mvdate = li.select_one('.txt_info > .txt_num').text
#     movie.append([rank, name, see, grade, num, mvdate])

# %%
# 한국은행의 기준금리 정보를 가져오는 예시

import requests
from bs4 import BeautifulSoup

url = 'https://www.bok.or.kr/portal/singl/baseRate/list.do?dataSeCd=01&menuNo=200643'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

#rate = soup.select_one('#content > div.table.tac > table > tbody > tr:nth-child(1) > td:nth-child(3)').text
#rate = soup.select('#content > div.table.tac > table > tbody > tr > td:nth-child(3)')[0].text
rate = soup.select('#content > div.table.tac > table > tbody > tr > td')[2].text # 여기서 보면 css 부모 자식 찾아가는것처럼 여기서도 똑같음!
print(f'기준금리: {rate}')
# Out:
# 기준금리: 3.50
